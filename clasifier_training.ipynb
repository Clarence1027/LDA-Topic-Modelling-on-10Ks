# %% [markdown]
# # 1. 机器学习模型训练 (shuwen)

# %%
# 随机生成一个特征矩阵X作为特征矩阵
n1 = 10000 # 特征维度
n2 = 1000  # 样本个数
import numpy as np
X = np.random.random((n1,n2))

# %%
y = np.random.randint(0,10,size=[n2,1])

# %%
X
# Out:
# array([[0.69915535, 0.59147231, 0.12841383, ..., 0.7343466 , 0.5956234 ,
#         0.40497928],
#        [0.42653768, 0.59055758, 0.63872118, ..., 0.64293083, 0.09683061,
#         0.37300882],
#        [0.37648212, 0.98427303, 0.78161729, ..., 0.85937732, 0.41378842,
#         0.41504589],
#        ...,
#        [0.2981085 , 0.51732033, 0.1264141 , ..., 0.2404279 , 0.12907528,
#         0.10724467],
#        [0.80094437, 0.0829601 , 0.11590539, ..., 0.89750689, 0.02565243,
#         0.95887219],
#        [0.62053917, 0.7601608 , 0.99626838, ..., 0.06816868, 0.24429441,
#         0.42642311]])

# %%
y
# Out:
# array([[7],
#        [1],
#        [0],
#        [9],
#        [5],
#        [5],
#        [0],
#        [2],
#        [0],
#        [2],
#        [1],
#        [3],
#        [3],
#        [4],
#        [6],
#        [2],
#        [6],
#        [5],
#        [1],
#        [3],
#        [0],
#        [7],
#        [1],
#        [7],
#        [3],
#        [5],
#        [7],
#        [1],
#        [5],
#        [8],
#        [4],
#        [5],
#        [7],
#        [0],
#        [1],
#        [3],
#        [2],
#        [3],
#        [6],
#        [3],
#        [4],
#        [3],
#        [5],
#        [2],
#        [8],
#        [5],
#        [4],
#        [8],
#        [7],
#        [2],
#        [0],
#        [7],
#        [7],
#        [4],
#        [2],
#        [8],
#        [6],
#        [3],
#        [0],
#        [6],
#        [5],
#        [1],
#        [3],
#        [2],
#        [7],
#        [4],
#        [3],
#        [5],
#        [7],
#        [4],
#        [3],
# ...

# %% [markdown]
# 以上准备工作已经完成，X为机器学习模型的输入，y为机器学习模型的标签，基于这样的数据进行模型训练。这里的数据只是随机产生的，仅仅是为了fit model，所以不必关注实际效果怎么样。但是数据的形式是我们将来会直接扔给这个部分的。
#
# 这里我们需要对比多种分类器的分类效果，做法就是上学期学的通过分割样本数据集or cross valiadation方法，这个负责这部分的组员自由发挥，reasonable就好。但是一定要体现出对比几种不同的分类器效果，比如用训练样本外数据计算mse。
#
# 最终的目标是保存已学习好的模型到本地，用于下一步主题模型的分类任务。
#
# 这里我列出几种常见的文本分类效果比较好的分类器，但也不局限，大家可以自由尝试：
#     - 朴素贝叶斯
#     - SVM可以尝试不同的核
#     - xgboost（这个是一个基于树的模型）
#     - KNN
#
# 这几个模型在sklearn里面都有，大家直接调用就好。好处是sklearn包的模型输入和输出对所有的模型都是一致的，而且本身也有划分数据集的函数。加油，我们接近尾声了～！
